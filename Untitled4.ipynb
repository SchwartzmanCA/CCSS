# %%
pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 19.0 MB/s eta 0:00:0031m19.9 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 9.5 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from d3graph import d3graph, vec2adjmat

# %%
# Create example network
source = ['node A','node F','node B','node B','node B','node A','node C','node Z']
target = ['node F','node B','node J','node F','node F','node M','node M','node A']
weight = [5.56, 0.5, 0.64, 0.23, 0.9, 3.28, 0.5, 0.45]
# Convert to adjacency matrix
adjmat = vec2adjmat(source, target, weight=weight)

# Initialize
d3 = d3graph()
# Proces adjmat
d3.graph(adjmat)
# Plot
d3.show()

# Make changes in node properties
d3.set_node_properties(color=adjmat.columns.values, label=['node 1','node 2','node 3','node 4','node 5','node 6','node 7'])
d3.show()
# Out:
# [d3graph] INFO> Converting source-target into adjacency matrix..
# [d3graph] INFO> Making the matrix symmetric..
# [d3graph] INFO> Set directed=True to see the markers!
# [d3graph] INFO> Keep only edges with weight>0
# [d3graph] INFO> Converting source-target into adjacency matrix..
# [d3graph] INFO> Making the matrix symmetric..
# [d3graph] INFO> Converting adjacency matrix into source-target..
# [d3graph] INFO> Number of unique nodes: 7
# [d3graph] INFO> Slider range is set to [0, 6]
# [d3graph] INFO> Write to path: [/tmp/tmpwylndkb7/d3graph.html]
# [d3graph] INFO> File already exists and will be overwritten: [/tmp/tmpwylndkb7/d3graph.html]
# [clustimage] >INFO> Add transparency to RGB colors (last column)
# [d3graph] INFO> Add transparency to RGB colors (last column)
# [d3graph] INFO> Number of unique nodes: 7
# [d3graph] INFO> Slider range is set to [0, 6]
# [d3graph] INFO> Write to path: [/tmp/tmp90xzabnt/d3graph.html]
# ...

# %%
adjmat
# Out:
# target  node A  node B  node F  node J  node M  node C  node Z
# source
# node A    0.00     0.0    5.56    0.00    3.28       0       0
# node B    0.00     0.0    1.13    0.64    0.00       0       0
# node F    0.00     0.5    0.00    0.00    0.00       0       0
# node J    0.00     0.0    0.00    0.00    0.00       0       0
# node M    0.00     0.0    0.00    0.00    0.00       0       0
# node C    0.00     0.0    0.00    0.00    0.50       0       0
# node Z    0.45     0.0    0.00    0.00    0.00       0       0

# %%
import json
with open("standards.json") as json_data:
    standards = json.load(json_data)

# %%
standards
# Out:
# {'standards': [{'name': 'K.CC.1',
#    'grade': 'Kindergarten',
#    'domain': 'Counting and Cardinality',
#    'description': 'Count to 100 by ones and by tens.',
#    'from': [],
#    'to': ['K.CC.2', 'K.CC.4a', '1.NBT.1']},
#   {'name': 'K.CC.2',
#    'grade': 'Kindergarten',
#    'domain': 'Counting and Cardinality',
#    'description': 'Count forward beginning from a given number within the known sequence (instead of having to begin at 1).',
#    'from': ['K.CC.1'],
#    'to': ['K.CC.4c']},
#   {'name': 'K.CC.3',
#    'grade': 'Kindergarten',
#    'domain': 'Counting and Cardinality',
#    'description': 'Write numbers from 0 to 20. Represent a number of objects with a written numeral 0-20 (with 0 representing a count of no objects).',
#    'from': [],
#    'to': ['1.NBT.1']},
#   {'name': 'K.CC.4a',
#    'grade': 'Kindergarten',
#    'domain': 'Counting and Cardinality',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(standards, orient='columns')
df
# Out:
#                                              standards
# 0    {'name': 'K.CC.1', 'grade': 'Kindergarten', 'd...
# 1    {'name': 'K.CC.2', 'grade': 'Kindergarten', 'd...
# 2    {'name': 'K.CC.3', 'grade': 'Kindergarten', 'd...
# 3    {'name': 'K.CC.4a', 'grade': 'Kindergarten', '...
# 4    {'name': 'K.CC.4b', 'grade': 'Kindergarten', '...
# ..                                                 ...
# 252  {'name': '8.SP.1', 'grade': '8th Grade', 'doma...
# 253  {'name': '8.SP.2', 'grade': '8th Grade', 'doma...
# 254  {'name': '8.SP.3', 'grade': '8th Grade', 'doma...
# 255  {'name': '8.SP.4', 'grade': '8th Grade', 'doma...
# 256                                                 {}
#
# [257 rows x 1 columns]

# %%
nstandards = pd.json_normalize(standards)
nstandards
# Out:
#                                            standards
# 0  [{'name': 'K.CC.1', 'grade': 'Kindergarten', '...

# %%
df = pd.DataFrame.from_dict(nstandards)
df
# Out:
#                                            standards
# 0  [{'name': 'K.CC.1', 'grade': 'Kindergarten', '...
